# %%
import math

def bolt_power_up(energy_level):
  return max(0, energy_level)


def stella_success(signal_strength):
  return 1 / (1 + math.exp(-signal_strength))

def glow_beacon(signal, threshold=5):
  return "BEACON ON" if signal >= threshold else "BEACON OFF"



print("Space Mission of The Solarverse: HELP THE SOLARVERSE")
print("Bolt, Stella, and Glow are trying to defeat Voidus, the black hole that is trying to destroy the universe")

bolt_energy_levels = list(map(int, input("Enter Bolt Energy Levels (e.g, -3 0 8 -2 5):").split()))
stella_signals = list(map(int, input("Enter Stella Signals (e.g, -10 -2 0 3 7):").split()))
glow_signals = list(map(int, input("Enter Glow Signals (e.g, 2 6 4 8 1):").split()))
beacon_threshold = int(input('Set the beacon threshold levels for Glow (default is 5):') or 5)



print("Bolt's Power-Up Challenge")
for energy in bolt_energy_levels:
  powered_up = bolt_power_up(energy)
  print(f"Energy Level:{energy} Powered Up: {powered_up}")
print()
print()
print()
print()
print("Stella Success Mission Prediction")
for signal in stella_signals:
  prob = stella_success(signal)
  print(f"Signal Strength: {signal} Stella Success Chances")
# Out:
# Space Mission of The Solarverse: HELP THE SOLARVERSE
# Bolt, Stella, and Glow are trying to defeat Voidus, the black hole that is trying to destroy the universe
# Enter Bolt Energy Levels (e.g, -3 0 8 -2 5):-4 3 8 2 3
# Enter Stella Signals (e.g, -10 -2 0 3 7):-6 -3 -2 8 7
# Enter Glow Signals (e.g, 2 6 4 8 1):6 2 9 1 4
# Set the beacon threshold levels for Glow (default is 5):5
# Bolt's Power-Up Challenge
# Energy Level:-4 Powered Up: 0
# Energy Level:3 Powered Up: 3
# Energy Level:8 Powered Up: 8
# Energy Level:2 Powered Up: 2
# Energy Level:3 Powered Up: 3
#
#
#
#
# Stella Success Mission Prediction
